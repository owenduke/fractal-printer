# %%
import numpy as np
import matplotlib.pyplot as plt
import quaternion

# %%
a = np.quaternion(1,1,0,0)
b = np.quaternion(1,0,1,0)
c = np.quaternion(0,1,0,0)
d = np.quaternion(0,2,1,1)

print(a*b)
print(a+b)

print(-(d*c + c*d)*c/2)
# Out:
# quaternion(1, 1, 1, 1)
# quaternion(2, 1, 1, 0)
# quaternion(0, 2, 0, 0)
