# %%
from fractal_printer.mesh import fractal_sdfs as fs, mesh_generation as mg
import numpy as np
from importlib import reload
import quaternion
from sdf import sdf
import matplotlib.pyplot as plt
from fractal_printer.paths import OUTPUT_DIR

# %%
reload(fs)
reload(mg)

c = quaternion.quaternion(0.1,0,0.8,0.05)
iterations = 60

settings = {"power": 2,
 "cx": -0.78,
 "cy": 0.0,
 "cz": -0.55,
 "cw": -0.24,
 "slice": 0.0,
 "offset": 0.015,
 "iterations": 15,
 "bailout": 100}

inner_julia = fs.quaternion_julia_sdf(
    **settings
)


final_sdf = inner_julia 

# Generate the points
mesh = mg.generate_mesh(
    final_sdf,
    samples = 2**28,
    simplify = 0.1,
    bounds = mg.box_bounds(size=3.5),
    save_path = OUTPUT_DIR / "egg_3.ply"
)
# Out:
# min -1.75, -1.75, -1.75
# max 1.75, 1.75, 1.75
# step 0.00542569, 0.00542569, 0.00542569
# 295408296 samples in 9261 batches with 8 workers
#   100% (9261 of 9261) [##############################] 0:00:40 0:00:00
# 8166 skipped, 702 empty, 393 nonempty
# 1052478 triangles in 39.6511 seconds
# Simplifying mesh by 0.1x ...
# Saving mesh to C:\Users\owenb\Code\personal\fractal-printer\outputs\egg_3.ply...

# %%
reload(fs)
reload(mg)

c = quaternion.quaternion(0.1,0,0.8,0.05)
iterations = 60

settings = {"power": 3,
 "cx": -0.3899999999999999,
 "cy": -0.3599999999999999,
 "cz": -0.6099999999999999,
 "cw": -0.06000000000000005,
 "slice": -0.06000000000000005,
 "offset": 0.012,
 "iterations": 7,
 "bailout": 100}

inner_julia = fs.quaternion_julia_sdf(
    **settings
)


final_sdf = inner_julia 

# Generate the points
mesh = mg.generate_mesh(
    final_sdf,
    samples = 2**28,
    simplify = 0.1,
    bounds = mg.box_bounds(size=3.5),
    save_path = OUTPUT_DIR / "egg_4.ply"
)
# Out:
# min -1.75, -1.75, -1.75
# max 1.75, 1.75, 1.75
# step 0.00542569, 0.00542569, 0.00542569
# 295408296 samples in 9261 batches with 8 workers
#   100% (9261 of 9261) [##############################] 0:00:53 0:00:00
# 7645 skipped, 848 empty, 768 nonempty
# 1947164 triangles in 53.3354 seconds
# Simplifying mesh by 0.1x ...
# Saving mesh to C:\Users\owenb\Code\personal\fractal-printer\outputs\egg_4.ply...
