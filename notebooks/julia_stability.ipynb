# %%
import numpy as np
import matplotlib.pyplot as plt
from fractal_printer.mesh import fractal_sdfs as fs
from sdf import sdf
from importlib import reload

# %%
# Plot a 2D slice of the distance function
reload(sdf)
reload(fs)

foo = fs.quaternion_julia_sdf(cx=0.4,cy=0.2,cz=0.3, bailout = 100, power = 3)
bar = lambda p: np.clip(foo(p),min=0)
sdf.core.show_slice(bar, y = 0.1, bounds =((-2,-2,-2),(2,2,2)) )
