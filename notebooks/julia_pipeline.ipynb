# %%
from fractal_printer.mesh import fractal_sdfs as fs, mesh_generation as mg
import numpy as np
from importlib import reload
import quaternion
from sdf import sdf
import matplotlib.pyplot as plt
from fractal_printer.paths import OUTPUT_DIR

# %%
# Define the SDF and make the base mesh

reload(fs)
reload(mg)

julia_sdf = fs.quaternion_julia_sdf(
    c = quaternion.quaternion(0.1,0.9,0.8,0.05),
    w = 0,
    iterations=60,
    offset=0.03,
    fudge_factor = 0.7
)

# Generate the points
mesh = mg.generate_mesh(
    julia_sdf,
    samples = 2**28,
    simplify = 0.5,
    save_path = OUTPUT_DIR / "ornament.ply"
)
# Out:
# min -1.4, -1.4, -1.4
# max 1.4, 1.4, 1.4
# step 0.00434055, 0.00434055, 0.00434055
# 295408296 samples in 9261 batches with 8 workers
#     0% (1 of 9261) [------------------------------] 0:00:00 0:02:31
#   100% (9261 of 9261) [##############################] 0:01:43 0:00:00
# 7712 skipped, 627 empty, 922 nonempty
# 2588880 triangles in 103.015 seconds
