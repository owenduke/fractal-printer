# %%
from fractal_printer import fractal_sdfs as fs
import numpy as np
from importlib import reload
import quaternion
from sdf import sdf
import matplotlib.pyplot as plt

# %%
# Define the SDF and make the base mesh

reload(fs)
julia_sdf = fs.quaternion_julia_sdf(
    c = quaternion.quaternion(0.4,0.2,0.5,0),
    w = 0,
    iterations=60,
    offset=0.005)

radius = 1.2
points = julia_sdf.generate(bounds = ((-radius,)*3,(radius,)*3),samples=2**22)
